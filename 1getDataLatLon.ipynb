# %%
import cdsapi 
import pandas as pd

# %%
import os

DIR_OUTPUT = './process/1nc/'
os.makedirs(DIR_OUTPUT, exist_ok=True)

c = cdsapi.Client()

lat, lon = 14.02436, 99.97319
year = 2023
month = [9, 10]

c.retrieve(
        'reanalysis-era5-single-levels',
        {
            'product_type': 'reanalysis',
            'format': 'netcdf',
            'variable': [
                '10m_u_component_of_wind', '10m_v_component_of_wind', '2m_dewpoint_temperature',
                '2m_temperature', 'downward_uv_radiation_at_the_surface', 'evaporation',
                'soil_temperature_level_1', 'surface_pressure', 'total_precipitation',
                'uv_visible_albedo_for_diffuse_radiation', 'uv_visible_albedo_for_direct_radiation'
            ],
            'year' : year,
            'month' : month,
            'day' : [str(i) for i in range(1, 32)],
            'time' : [
                '00:00', '06:00', '12:00', '18:00'
            ],
            'area' : [lat, lon, lat, lon]
        },
        f"{DIR_OUTPUT}KU-Kamphaeng-Saen.nc")
# Out:
# 2024-05-19 20:10:32,847 INFO Welcome to the CDS
# 2024-05-19 20:10:32,847 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-single-levels
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 12
#       9 year = 2023
#      10 month = [9, 10]
# ---> 12 c.retrieve(
#      13         'reanalysis-era5-single-levels',
#      14         {
#      15             'product_type': 'reanalysis',
#      16             'format': 'netcdf',
#      17             'variable': [
#      18                 '10m_u_component_of_wind', '10m_v_component_of_wind', '2m_dewpoint_temperature',
#      19                 '2m_temperature', 'downward_uv_radiation_at_the_surface', 'evaporation',
#      20                 'soil_temperature_level_1', 'surface_pressure', 'total_precipitation',
# ...
